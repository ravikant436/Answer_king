# %% [markdown]
# #Installation and Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import re
import os

# %%
pip install tagme
# Out:
# Collecting tagme
#   Downloading https://files.pythonhosted.org/packages/7b/ea/bbdb46fec64423ea0b28fd508ab8ee8b59a918db090d5e073dd6f3bf227f/tagme-0.1.3-py2.py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from tagme) (0.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tagme) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from tagme) (2.8.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tagme) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tagme) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tagme) (2020.11.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tagme) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tagme) (3.0.4)
# Installing collected packages: tagme
# Successfully installed tagme-0.1.3

# %%
import sys
# !{sys.executable} -m pip install -U germanetpy
# Out:
# Collecting germanetpy
#   Downloading https://files.pythonhosted.org/packages/12/16/d17862422eae401706fc31b0f5eb3d45d18bef211a3b284167c18cd24935/germanetpy-0.2.1-py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 3.2MB/s
# Requirement already satisfied, skipping upgrade: tqdm>=4.14 in /usr/local/lib/python3.6/dist-packages (from germanetpy) (4.41.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.18.1 in /usr/local/lib/python3.6/dist-packages (from germanetpy) (1.18.5)
# Collecting fastenum>=0.0.1
#   Downloading https://files.pythonhosted.org/packages/62/8d/364b584a546dbce6e046efaa7926446f4f681900c6992258c740f73c39fb/fastenum-0.0.8.tar.gz
# Collecting python-Levenshtein==0.12.0
#   Downloading https://files.pythonhosted.org/packages/42/a9/d1785c85ebf9b7dfacd08938dd028209c34a0ea3b1bcdb895208bd40a67d/python-Levenshtein-0.12.0.tar.gz (48kB)
#      |████████████████████████████████| 51kB 3.5MB/s
# Collecting lxml>=4.4.2
#   Downloading https://files.pythonhosted.org/packages/64/28/0b761b64ecbd63d272ed0e7a6ae6e4402fc37886b59181bfdf274424d693/lxml-4.6.1-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 6.3MB/s
# Collecting pytest>=5.3.2
#   Downloading https://files.pythonhosted.org/packages/b1/ee/53945d50284906adb1e613fabf2e1b8b25926e8676854bb25b93564c0ce7/pytest-6.1.2-py3-none-any.whl (272kB)
#      |████████████████████████████████| 276kB 46.6MB/s
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from python-Levenshtein==0.12.0->germanetpy) (50.3.2)
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.12; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from pytest>=5.3.2->germanetpy) (2.0.0)
# Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python3.6/dist-packages (from pytest>=5.3.2->germanetpy) (20.4)
# Collecting pluggy<1.0,>=0.12
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest>=5.3.2->germanetpy) (20.3.0)
# Requirement already satisfied, skipping upgrade: toml in /usr/local/lib/python3.6/dist-packages (from pytest>=5.3.2->germanetpy) (0.10.2)
# Requirement already satisfied, skipping upgrade: iniconfig in /usr/local/lib/python3.6/dist-packages (from pytest>=5.3.2->germanetpy) (1.1.1)
# Requirement already satisfied, skipping upgrade: py>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from pytest>=5.3.2->germanetpy) (1.9.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest>=5.3.2->germanetpy) (3.4.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->pytest>=5.3.2->germanetpy) (2.4.7)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from packaging->pytest>=5.3.2->germanetpy) (1.15.0)
# Building wheels for collected packages: fastenum, python-Levenshtein
#   Building wheel for fastenum (setup.py) ... done
#   Created wheel for fastenum: filename=fastenum-0.0.8-cp36-none-any.whl size=10730 sha256=d63af67b03479136f400a47c748aab5d4b18f221b31ab505053a633ec309fbc2
#   Stored in directory: /root/.cache/pip/wheels/25/fa/61/cd759a92ef498fb1bd56e306aed9e44b92c6ceb039ba0045c6
#   Building wheel for python-Levenshtein (setup.py) ... done
#   Created wheel for python-Levenshtein: filename=python_Levenshtein-0.12.0-cp36-cp36m-linux_x86_64.whl size=144799 sha256=486e80326ca478b4e66b3020a4ea881d665f3ddfdc39e80fc90582af1dbdc286
#   Stored in directory: /root/.cache/pip/wheels/de/c2/93/660fd5f7559049268ad2dc6d81c4e39e9e36518766eaf7e342
# Successfully built fastenum python-Levenshtein
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: fastenum, python-Levenshtein, lxml, pluggy, pytest, germanetpy
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# Successfully installed fastenum-0.0.8 germanetpy-0.2.1 lxml-4.6.1 pluggy-0.13.1 pytest-6.1.2 python-Levenshtein-0.12.0

# %%
from pathlib import Path
from germanetpy.germanet import Germanet

data_path = "/content/drive/My Drive/Colab Notebooks/AutomaticOnt/germanet/GN_V150/GN_V150_XML"
frequencylist_nouns = "/content/drive/My Drive/Colab Notebooks/AutomaticOnt/germanet/GN_V150/FreqLists/noun_freqs_decow14_16.txt"
germanet = Germanet(data_path)
# Out:
# Load GermaNet data...: 100%|█████████▉| 99.99999999999996/100 [01:21<00:00,  1.22it/s]
# Load Wictionary data...: 100%|██████████| 100.0/100 [00:03<00:00, 31.06it/s]
# Load Ili records...: 100%|██████████| 100.0/100 [00:01<00:00, 95.36it/s]

# %% [markdown]
# #Files Reading

# %% [markdown]
# **First Reading Datev Glossary terms**

# %%
glossary_file = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/AutomaticOnt/Datev_content/glossary.xlsx')
glossary_file = glossary_file[['Term', 'Status']]
glossary_file.head()
# Out:
#                        Term      Status
# 0  (Kanzlei-)Rechnungswesen  deprecated
# 1                     (pro)  deprecated
# 2              @-Consulting   preferred
# 3                **ANREDE**    non-term
# 4                 **DATUM**    non-term

# %%
glossary_file['Status'].unique()
# Out:
# array(['deprecated', 'preferred', 'non-term', 'admitted', 'proposed'],
#       dtype=object)

# %%
# saving all terms in a list and lower casing all terms
glossary_terms = list(glossary_file['Term'])
for i in range(len(glossary_terms)):
  glossary_terms[i] = glossary_terms[i].lower()

# %%
from os import listdir
from os.path import isfile, join
import json
import re
onlyfiles = [f for f in listdir("/content/drive/My Drive/Colab Notebooks/AutomaticOnt/Corpus/GermanLegalFiles/all_files/") if isfile(join("/content/drive/My Drive/Colab Notebooks/AutomaticOnt/Corpus/GermanLegalFiles/all_files/", f))]
onlyfiles.sort()

folder_path = "/content/drive/My Drive/Colab Notebooks/AutomaticOnt/Corpus/GermanLegalFiles/all_files/"

# %%
# 0019421
# 0057729
# 0061693
# 0077309
# 0084252
# 0105285
# 0124330
# 0138573
# 0165920
# 0173722
# 0380318
# 0382251
# 0382370
# 0443434
# 0556087
# 0578343
# 1150029

# %%
def remove_html_tags(text):
  text_arr = text.split('</lxbase:bibliographische-angaben>')
  text_use = text_arr[1]
  # marking para
  text_use = re.sub(re.compile('</lxbase:a>'), '^^para^^', text_use)
  # remove new lines
  text_use = re.sub(re.compile('\n'), ' ', text_use)
  clean = re.compile('<.*?>')
  return re.sub(clean, '', text_use)

# %%
def getLegalParaList(data):
  data = data.replace('EStG', 'EStG|').replace('EStG|)', 'EStG)|').replace('GDL', 'GDL|').replace('BewG', 'BewG|').replace('EStDV', 'EStDV|').replace('AO', 'AO|')

  words_pattern = r'§[ §a-zA-Z0-9,.]+'
  legal_para_list = re.findall(words_pattern, data, flags=re.IGNORECASE)
  legal_para_list = list(set(legal_para_list))
  return legal_para_list

def getHeadingParaSequence(data):
  # mark paragraphs in the document
  data_arr = data.split('^^para^^')
  # get type of text chunks - roman heading, number heading or paragraph
  roman_heading_pattern = r"[IXV]+[. ][^\n]+"
  num_heading_pattern = r"[0-9]+. [^\n]+"
  heading_para_list = []
  for sequence in data_arr:
    if re.match(roman_heading_pattern, sequence):
      heading_para_list.append(['roman_head', sequence])
    elif re.match(num_heading_pattern, sequence):
      heading_para_list.append(['num_head', sequence])
    else:
      heading_para_list.append(['para', sequence])
  sequence_type_df = pd.DataFrame(heading_para_list, columns=['type', 'text'])
  return sequence_type_df

# %%
def fileToHeadParaPair(fileFullpath):
  with open(fileFullpath, 'r') as file:
    data = file.read()
  data = remove_html_tags(data)
  
  # get Heading Para Sequence
  sequence_type_df = getHeadingParaSequence(data)
  # Prepare Heading Para pair 
  document_sequence_list = []
  num_head_flag = 0
  roman_head_flag = 0
  para_text = ""
  heading_text = ""
  for index, rows in sequence_type_df.iterrows():
    seq_type = rows["type"]
    seq_text = rows["text"]

    if seq_type == "roman_head":
      if para_text != "":
        document_sequence_list.append([heading_text, para_text])
        heading_text = ""
        para_text = ""
        roman_head_flag = 0
      roman_head_flag = roman_head_flag + 1
      heading_text = heading_text + seq_text
    elif seq_type == "num_head":
      num_head_flag = num_head_flag + 1
      if roman_head_flag > 0:
        para_text = para_text + seq_text
      else:
        if para_text != "":
          document_sequence_list.append([heading_text, para_text])
          roman_head_flag = 0
          para_text = ""
          heading_text = ""
        heading_text = heading_text + seq_text
    else:
      para_text = para_text + seq_text

  document_sequence_df = pd.DataFrame(document_sequence_list, columns=["heading", "para"])

  return document_sequence_df

# %%
# sequence_type_df = fileToHeadParaPair(folder_path + "0578343.xml")
# sequence_type_df.head()
# for i in range(len(sequence_type_df)): 
#   print(sequence_type_df.loc[i, "type"], sequence_type_df.loc[i, "text"])

# %% [markdown]
# #Processing Heading and Para

# %%
heading_para_df = fileToHeadParaPair(folder_path+ onlyfiles[1])

# %%
heading_para_df.head()
# Out:
#                                              heading                                               para
# 0                                                     Bodengewinnbesteuerung nach § 55 EStGInhaltsüb...
# 1          I. Allgemeines zur Bodengewinnbesteuerung  1. Gesetzliche Grundlagen2. Zeitlicher Anwendu...
# 2  III. Land- und forstwirtschaftlich genutzte Gr...  1. Allgemeines2. Wirtschaftliches Eigentum3. G...
# 3  IV. Übertragung eines land- und forstwirtschaf...  1. Übertragung des Betriebs mit allen wesentli...
# 4  V. Die Fälle der Betriebsaufgabe bei land- und...       1. Betriebseinstellung2. Betriebsverpachtung

# %%
def getSynsets(word):
  synsets = germanet.get_synsets_by_orthform(word)
  return synsets

def getFirstSynset(word):
  synsets = getSynsets(word)
  if len(synsets) > 0:
    first_synset = germanet.get_synset_by_id(synsets[0].id)
  else:
    return 0
  return first_synset

# %%
def getHypernymPathsIds(synset):
  paths = synset.hypernym_paths()
  paths_ids = []
  for path in paths:
    temp_path_ids = []
    for item in path:
      temp_path_ids.append(item.id)
    paths_ids.append(temp_path_ids)
  return paths_ids

def issubclass(a_synset, b_synset):
  a_hyper_paths = getHypernymPathsIds(a_synset)
  b_hyper_paths = getHypernymPathsIds(b_synset)
  a_synset_id = a_synset.id
  b_synset_id = b_synset.id
  # check if b is in hypernyms path of a
  flag = 0
  for path in a_hyper_paths:
    if b_synset_id in path:
      flag = 1                # it means b_synset is hypernym of a_synset
  return flag

# a_synset = getFirstSynset("Oberfinanzdirektion")
# b_synset = getFirstSynset("Finanzamt")
# issubclass(a_synset, b_synset)

# %%
import tagme
# Set the authorization token for subsequent calls.
tagme.GCUBE_TOKEN = "0cd18564-f4c2-4891-af4d-6745c23b43a4-843339462"

def getTermList(text):
  all_terms = []
  # doc = nlp(text) 
  # for token in doc: 
  #   if getFirstSynset(token.lemma_) != 0:
  #     all_terms.append(token.lemma_)

  # get terms using Tagme
  temp_annotations = tagme.annotate(text, lang="de")
  if len(temp_annotations.annotations) > 0:
    for ann in temp_annotations.get_annotations(0.1):
      if getFirstSynset(ann.mention) != 0:
        all_terms.append(ann.mention)
      elif getFirstSynset(ann.entity_title) != 0:
        all_terms.append(ann.entity_title)
        # all_terms.append(ann.mention)
      else:
        all_terms.append(ann.mention)
  all_terms = list(set(all_terms))
  return all_terms

# %%
# word_a = "ausländische"
# print(len(word_a.split(' ')))
# word_b = "§ 34d EStG"
# para = "ausländische Einkünfte nach § 34d EStG"
# conn_str_list = re.findall(rf'{word_a}.+? {word_b}',para)
# print(conn_str_list)
# margin_length = len(word_a.split(' ')) + len(word_b.split(' ')) + 6
# if len(conn_str_list) > 0:
#   for sent in conn_str_list:
#     if len(sent.split(' ')) < margin_length and len(sent.split(' ')) > 2:
#       filtered_sent = sent.rstrip("§ 34d EStG").strip()
#       left_word_arr = word_a.split(' ')
#       for s in left_word_arr:
#         filtered_sent = filtered_sent.lstrip(s).strip()
#       print(filtered_sent)
# Out:
# 1
# ['ausländische Einkünfte nach § 34d EStG']
# Einkünfte nach

# %%
 distance_relation_pair = []
 paragraphs = []
 dirty_tags = ['Abs', 'EStG', 'bzw', 'EStR', 'EStDV', 'BewG', 'DM', 'GDL', 'AO']
 for index, rows in heading_para_df.iterrows():
  para_id = "para_" + str(index)

  heading = rows["heading"]
  para = rows["para"]

  # Saving all paragraphs in a different dataframe
  paragraphs.append([para_id, para])

  if heading != "":
    head_terms = list(set(getTermList(heading))) + getLegalParaList(heading)
  else:
    head_terms = []
  if para != "":
    para_terms = list(set(getTermList(para))) + getLegalParaList(para)
  else:
    para_terms = []

  # check if para terms are subclass of any head_term
  # head_para_pair = []
  # for para_term in para_terms:
  #   for head_term in head_terms:
  #     para_synset = getFirstSynset(para_term)
  #     head_synset = getFirstSynset(head_term)
  #     if para_synset != head_synset:
  #       if para_synset != 0 and head_synset != 0:
  #         if issubclass(para_synset, head_synset) == 1:
  #           head_para_pair.append([para_term, 'isSubclassof', head_term])
  #         else:
  #           head_para_pair.append([para_term, 'hasTheme', head_term])
  
  # # check if para terms have subclasses with each others
  # para_para_pair = []  #(child, parent)
  # for para_term1 in para_terms:
  #   for para_term2 in para_terms:
  #     a_synset = getFirstSynset(para_term1)
  #     b_synset = getFirstSynset(para_term2)
  #     if a_synset != b_synset:
  #       if a_synset != 0 and b_synset != 0:
  #           if issubclass(a_synset, b_synset) == 1:
  #             para_para_pair.append([para_term1, 'isSubclassof', para_term2])

  # Check if there is single or double word relation between any word pairs
  # in a Single paragraph
  for i in range(0, len(para_terms)):
    for j in range(i+1, len(para_terms)):
      glossary_status = ""
      word_a = para_terms[i]
      word_b = para_terms[j]
      if word_a in dirty_tags or word_b in dirty_tags:
        continue;

      # Check if subject or object are in Glossary list
      if word_a in glossary_terms:
        glossary_status = word_a + " |"
      
      if word_b in glossary_terms:
        glossary_status = glossary_status + "| " + word_b

      # Maximum 6 word relation between source and target
      margin_length = len(word_a.split(' ')) + len(word_b.split(' ')) + 6

      # Extracting Relation between two tags
      conn_str_list = re.findall(rf'{word_a}.+? {word_b}',para)
  
      if len(conn_str_list) > 0:
        for sent in conn_str_list:
          if len(sent.split(' ')) < margin_length and len(sent.split(' ')) > 4:
            filtered_sent = sent.rstrip(word_b).strip()
            left_word_arr = word_a.split(' ')
            for s in left_word_arr:
              filtered_sent = filtered_sent.lstrip(s).strip()
            if filtered_sent != '':
              distance_relation_pair.append([word_a, filtered_sent, word_b, para_id, glossary_status])

temp_relation_df = pd.DataFrame(distance_relation_pair, columns=['Word1', 'Relation', 'Word2', 'Para_id', 'Glossary_status'])
paragraph_df = pd.DataFrame(paragraphs, columns=['Para_id', 'Text'])
# para_para_relation_df = pd.DataFrame(para_para_pair, columns=['Word1', 'Relation', 'Word2'])
# head_para_relation_df = pd.DataFrame(head_para_pair, columns=['Word1', 'Relation', 'Word2'])

# %%
paragraph_df
# Out:
#     Para_id                                               Text
# 0    para_0  Bodengewinnbesteuerung nach § 55 EStGInhaltsüb...
# 1    para_1  1. Gesetzliche Grundlagen2. Zeitlicher Anwendu...
# 2    para_2  1. Allgemeines2. Wirtschaftliches Eigentum3. G...
# 3    para_3  1. Übertragung des Betriebs mit allen wesentli...
# 4    para_4       1. Betriebseinstellung2. Betriebsverpachtung
# 5    para_5  1. Allgemeines2. Ausgangsbeträge nach § 55 Abs...
# 6    para_6  1. Antragstellung, Ermittlung und Feststellung...
# 7    para_7  1. Gesetzliche GrundlagenDurch das Zweite Steu...
# 8    para_8  1. Ernsthafte land- und forstwirtschaftliche B...
# 9    para_9  1. Allgemeines  Land- und forstwirtschaftlich ...
# 10  para_10  1. Übertragung des Betriebs mit allen wesentli...
# 11  para_11  1. BetriebseinstellungWird die land- und forst...
# 12  para_12  1. Allgemeines  Es wird auf den Wortlaut des §...
# 13  para_13  1. Antragstellung, Ermittlung und Feststellung...
# 14  para_14  Beispiel:Doppelter Ausgangsbetrag  5.000 DMVer...
# 15  para_15  1. Was bei der wertmäßigen Erfassung des Grund...
# 16  para_16  1. Bei Gewinnermittlung nach § 4 Abs. 3 EStG u...
# 17  para_17  1. AllgemeinesDer Freibetrag nach § 14 EStG is...
# 18  para_18  Im Interesse der Arbeitsvereinfachung sowie ei...

# %%
temp_relation_df
# Out:
#                                        Word1  ...                            Word2
# 0                                Festsetzung  ...                  Vorauszahlungen
# 1                                    höheren  ...                              Abs
# 2                                     Bodens  ...                      Besteuerung
# 3                                     Bodens  ...                 Gewinnermittlung
# 4                                     Bodens  ...                            Boden
# 5                                Besteuerung  ...                 Gewinnermittlung
# 6                                Besteuerung  ...                            Boden
# 7                                     Steuer  ...                             VIII
# 8                                       VIII  ...                               IX
# 9                                       gemä  ...                              Abs
# 10                          Gewinnermittlung  ...                              Abs
# 11                          Gewinnermittlung  ...                              Abs
# 12                                  Vermögen  ...                            Boden
# 13                                    Bodens  ...                            Boden
# 14                                      Land  ...                      selbständig
# 15                                       ert  ...                           worden
# 16                               Veräußerung  ...                            Boden
# 17                               Festsetzung  ...                  Vorauszahlungen
# 18                               selbständig  ...                            Boden
# 19                                 Belastung  ...                          Betrieb
# 20                                 Belastung  ...                 Betriebsvermögen
# 21                                    Gemüse  ...                       Baumschule
# 22                                    Gemüse  ...                          Weinbau
# 23                                 Anwendung  ...                         Regelung
# 24                                   Nutzung  ...                       Grundstück
# 25                                   Nutzung  ...                       Grundstück
# 26                                   Nutzung  ...               landwirtschaftlich
# 27                       Betriebsveräußerung  ...                          Betrieb
# 28                               Erbbaurecht  ...                       Grundstück
# 29                                  Landwirt  ...                       Grundstück
# 30                                   Aufgabe  ...                          Betrieb
# 31                                      Zeit  ...               landwirtschaftlich
# 32                                      Zeit  ...                      Verpachtung
# 33                                     weder  ...                          Betrieb
# 34                                     weder  ...                              Zug
# 35                                   Betrieb  ...                       Grundstück
# 36                                   Betrieb  ...                       Grundstück
# 37                                   Betrieb  ...                       Nießbrauch
# 38                                   Betrieb  ...               landwirtschaftlich
# 39                                   Betrieb  ...               landwirtschaftlich
# 40                                   Betrieb  ...                         Regelung
# 41                                Eigentümer  ...                          Dritten
# 42                                Grundstück  ...                           Steuer
# 43                                Grundstück  ...                             Land
# 44                                Grundstück  ...                  Forstwirtschaft
# 45                                   Obstbau  ...                  Forstwirtschaft
# 46                                      BewG  ...                           Unland
# 47                                   Flächen  ...               landwirtschaftlich
# 48                                   Flächen  ...               landwirtschaftlich
# 49                                   Flächen  ...               landwirtschaftlich
# 50                                   Flächen  ...               landwirtschaftlich
# 51                                   Flächen  ...                 Betriebsvermögen
# 52                                    Steuer  ...             Veranlagungszeitraum
# 53                                    worden  ...                         Entnahme
# 54                                verpachtet  ...                         Entnahme
# 55                                 Zeitpunkt  ...                      Verpachtung
# 56                                Baumschule  ...                           Hopfen
# 57                                Baumschule  ...                          Spargel
# 58                                 Rebfläche  ...                             Wald
# 59                                    Eltern  ...                      Verpachtung
# 60                                     Gerät  ...                          Düngung
# 61                                     Gerät  ...                        laufenden
# 62                                    Kultur  ...                              Zug
# 63                                      Land  ...                  Forstwirtschaft
# 64                           Forstwirtschaft  ...                              Zug
# 65                           Steuererklärung  ...             Veranlagungszeitraum
# 66                                   Weinbau  ...                          Spargel
# 67                                  Maschine  ...                        laufenden
# 68                                       grö  ...                              Zug
# 69                                    Eltern  ...                       Elternteil
# 70                                    Eltern  ...                             Kind
# 71                                Güterstand  ...                          Flächen
# 72                                Güterstand  ...                Gütergemeinschaft
# 73                                Wirtschaft  ...        Wirtschaftliches Eigentum
# 74                                Wirtschaft  ...                            Boden
# 75                        Herausgabeanspruch  ...                   wirtschaftlich
# 76                        Herausgabeanspruch  ...                        Bedeutung
# 77                          Verwaltungsrecht  ...                             Kind
# 78                              Gesellschaft  ...                         Ehegatte
# 79                              Gesellschaft  ...                              Ehe
# 80                              Gesellschaft  ...                Gütergemeinschaft
# 81                                       bzw  ...              forstwirtschaftlich
# 82                                       bzw  ...                          Betrieb
# 83                                       bzw  ...  land- und forstwirtschaftlichen
# 84                          Betriebsvermögen  ...                             Land
# 85                          Betriebsvermögen  ...                          Betrieb
# 86                          Betriebsvermögen  ...                          Betrieb
# 87                          Betriebsvermögen  ...                  Forstwirtschaft
# 88                          Betriebsvermögen  ...                       Grundstück
# 89                          Betriebsvermögen  ...                         Eigentum
# 90                          Betriebsvermögen  ...                    Vorbehaltsgut
# 91                                      Land  ...                          Flächen
# 92                                      Land  ...              forstwirtschaftlich
# 93                                      Land  ...                  Forstwirtschaft
# 94                                  Ehegatte  ...                          Betrieb
# 95                                  Ehegatte  ...                       Grundstück
# 96                                   Flächen  ...                              Ehe
# 97                                   Flächen  ...                          Betrieb
# 98                                   Flächen  ...                          Betrieb
# 99                       forstwirtschaftlich  ...                              Ehe
# 100                      forstwirtschaftlich  ...                          Betrieb
# 101                      forstwirtschaftlich  ...                    Vorbehaltsgut
# 102                     Mitunternehmerschaft  ...                Wirtschaftsgütern
# 103                     Mitunternehmerschaft  ...                              Ehe
# 104                        Wirtschaftsgütern  ...                            Boden
# 105                               steuerlich  ...                              Ehe
# 106                           wirtschaftlich  ...                              Ehe
# 107                           wirtschaftlich  ...                          Betrieb
# 108                           wirtschaftlich  ...                          Betrieb
# 109                           wirtschaftlich  ...                    Vorbehaltsgut
# 110                                      Ehe  ...                          Betrieb
# 111                                      Ehe  ...                       Grundstück
# 112  land- und forstwirtschaftlicher Betrieb  ...                    Vorbehaltsgut
# 113                                  Betrieb  ...                  Forstwirtschaft
# 114                                  Betrieb  ...                       Grundstück
# 115                                  Betrieb  ...                       Grundstück
# 116                                  Betrieb  ...                    Vorbehaltsgut
# 117                                    Rolle  ...                        Gesamtgut
# 118                               Grundstück  ...                    Vorbehaltsgut
# 119                               Grundstück  ...                        Gesamtgut
# 120          land- und forstwirtschaftlichen  ...                Grundstücksfläche
# 121                Wirtschaftliches Eigentum  ...                         Eigentum
# 122                            Vorbehaltsgut  ...                        Gesamtgut
# 123                                 Inventar  ...                          Betrieb
# 124                           Privatvermögen  ...                          Betrieb
# 125                            unentgeltlich  ...                       Nachfolger
# 126                            unentgeltlich  ...                       Nachfolger
# 127                            unentgeltlich  ...                       Nachfolger
# 128                            unentgeltlich  ...                          Betrieb
# 129                         Betriebsvermögen  ...                 stillen Reserven
# 130                                Wahlrecht  ...                           wählen
# 131                               Nachfolger  ...                          Betrieb
# 132                               Nachfolger  ...                          Betrieb
# 133                               Nachfolger  ...                          Betrieb
# 134                               Nachfolger  ...                          Betrieb
# 135                               Nachfolger  ...                       Grundstück
# 136                               übertragen  ...                          Betrieb
# 137                               Verhältnis  ...                          Betrieb
# 138                                 Landwirt  ...                          Betrieb
# 139                                 Landwirt  ...  land- und forstwirtschaftlichen
# 140                          Bewirtschaftung  ...                          Betrieb
# 141                              Übertragung  ...                          Betrieb
# 142                                    EStDV  ...                          Betrieb
# 143                                Bedeutung  ...                          Betrieb
# 144                               Grundstück  ...                Steuerpflichtiger
# 145                           Wirtschaftsgut  ...                         Entnahme
# 146                                 Inventar  ...                       verpachtet
# 147                                     Fall  ...                      Veräußerung
# 148                           Privatvermögen  ...                    Steuerpflicht
# 149                           Privatvermögen  ...                 Betriebsvermögen
# 150                           Privatvermögen  ...                         Landwirt
# 151                           Privatvermögen  ...                          Betrieb
# 152                           Privatvermögen  ...                          Betrieb
# 153                           Privatvermögen  ...                 Steuerpflichtige
# 154                                     lich  ...                 Betriebsvermögen
# 155                                     lich  ...                         Landwirt
# 156                                     lich  ...                          Betrieb
# 157                                     lich  ...                          Betrieb
# 158                                     lich  ...                          Betrieb
# 159                                     lich  ...                          Betrieb
# 160                                     lich  ...                          Betrieb
# 161                                     lich  ...                       Grundstück
# 162                                     lich  ...                       verpachtet
# 163                                     lich  ...                           Fläche
# 164                                     lich  ...                              Abs
# 165                                     lich  ...                      Verpachtung
# 166                            Steuerpflicht  ...                 Betriebsvermögen
# 167                            Steuerpflicht  ...                          Betrieb
# 168                            Steuerpflicht  ...                              Abs
# 169                            Steuerpflicht  ...                      Verpachtung
# 170                         Betriebsvermögen  ...                 Steuerpflichtige
# 171                         Betriebsvermögen  ...                         Entnahme
# 172                                Anwendung  ...                      Verpachtung
# 173                                Wahlrecht  ...                               ob
# 174                                Wahlrecht  ...                           Fläche
# 175                                verfahren  ...                        Forstwirt
# 176                                     Ware  ...                 Wirtschaftsgüter
# 177                                      GDL  ...                          Betrieb
# 178                                 Landwirt  ...                           Fläche
# 179                                 Landwirt  ...                           Fläche
# 180                                 Landwirt  ...                           Fläche
# 181                          Betriebsaufgabe  ...                      Verpachtung
# 182                                      ert  ...                          Betrieb
# 183                                      ert  ...                      Verpachtung
# 184                                      ert  ...                      Verpachtung
# 185                               Nebenberuf  ...                           Fläche
# 186                                   wählen  ...                       verpachtet
# 187                              Veräußerung  ...                          Betrieb
# 188                                 Einnahme  ...                      Verpachtung
# 189                         Wirtschaftsgüter  ...                          Betrieb
# 190                         Wirtschaftsgüter  ...                          Betrieb
# 191                                  Betrieb  ...                 Steuerpflichtige
# 192                                  Betrieb  ...                           Fläche
# 193                         Steuerpflichtige  ...                              Abs
# 194                         Steuerpflichtige  ...                      Verpachtung
# 195                                       ob  ...                       verpachtet
# 196                                       ob  ...                           Fläche
# 197                                      Abs  ...                             EStR
# 198                                  Flächen  ...            Liegenschaftskataster
# 199                            Steuerpflicht  ...                         Teilwert
# 200                                 Teilwert  ...                            Boden
# 201                                 Teilwert  ...                            Boden
# 202                                     u. U  ...                  Erbschaftsteuer
# 203                                     u. U  ...                         Vermögen
# 204                                     u. U  ...                   Vermögensteuer
# 205                              Grundsteuer  ...                  Erbschaftsteuer
# 206                              Grundsteuer  ...                         Vermögen
# 207                              Grundsteuer  ...                   Vermögensteuer
# 208                                       DM  ...                          Verlust
# 209                            Steuerpflicht  ...                 Gewinnermittlung
# 210                         Betriebsvermögen  ...                            Boden
# 211                                   Bodens  ...                 Gewinnermittlung
# 212                       Anschaffungskosten  ...                            Werte
# 213                       Anschaffungskosten  ...                       aktivieren
# 214                                 Teilwert  ...                          Einlage
# 215                                 Teilwert  ...                              Abs
# 216                                 bewerten  ...                            Werte
# 217                         Gewinnermittlung  ...                              Abs
# 218                                    Werte  ...                        § 55 EStG
# 219                                   Werten  ...                        § 55 EStG
# 220                               aktivieren  ...                            Boden
# 221                           Anlagevermögen  ...                      Veräußerung
# 222                           Anlagevermögen  ...                        Zeitpunkt
# 223                           Strukturwandel  ...                   Gewerbebetrieb
# 224                           Strukturwandel  ...                          Gewerbe
# 225                       Herstellungskosten  ...                 Wirtschaftsgüter
# 226                                   Bodens  ...                          Betrieb
# 227                                Wahlrecht  ...               Anschaffungskosten
# 228                                 Landwirt  ...                       Grundstück
# 229                          Betriebsausgabe  ...                             Flie
# 230                       Anschaffungskosten  ...                      Veräußerung
# 231                       Anschaffungskosten  ...                        Zeitpunkt
# 232                                    weder  ...                          Betrieb
# 233                              Veräußerung  ...                 Wirtschaftsgüter
# 234                              Veräußerung  ...                              Abs
# 235                              Veräußerung  ...                         Entnahme
# 236                         Wirtschaftsgüter  ...                        Zeitpunkt
# 237                                  Betrieb  ...                 Gewinnermittlung
# 238                                  Betrieb  ...                             Flie
# 239                         Gewinnermittlung  ...                              Abs
# 240                         Gewinnermittlung  ...                              Abs
# 241                                Zeitpunkt  ...                         Entnahme
# 242                                Einkünfte  ...                               DM
# 243                                Einkünfte  ...                               DM
# 244                                Einkünfte  ...                             Land
# 245                                Einkünfte  ...                             Land
# 246                                Einkünfte  ...                             Land
# 247                                Einkünfte  ...                  Forstwirtschaft
# 248                                Einkünfte  ...                  Forstwirtschaft
# 249                                Einkünfte  ...                  Forstwirtschaft
# 250                                Einkünfte  ...                        Forstwirt
# 251                                Einkünfte  ...                        Forstwirt
# 252                                Einkünfte  ...                        Forstwirt
# 253                                  Tilgung  ...                         Schulden
# 254                                  Tilgung  ...                         Schulden
# 255                                  Tilgung  ...                         Schulden
# 256                                  Tilgung  ...                          Betrieb
# 257                                  Tilgung  ...                     anderen land
# 258                                Einkommen  ...                               DM
# 259                                Einkommen  ...                               DM
# 260                                Einkommen  ...                               DM
# 261                                Einkommen  ...                              bzw
# 262                                   Grenze  ...                               DM
# 263                           Sonderausgaben  ...                               DM
# 264                            erbberechtigt  ...                      Vermächtnis
# 265                             Kalenderjahr  ...                  Wirtschaftsjahr
# 266                             Kalenderjahr  ...                  Wirtschaftsjahr
# 267                             Kalenderjahr  ...                  Wirtschaftsjahr
# 268                                       DM  ...                       Freibetrag
# 269                                       DM  ...                       Freibetrag
# 270                                       DM  ...                           Gewinn
# 271                                       DM  ...                           Gewinn
# 272                                       DM  ...                  Wirtschaftsjahr
# 273                         Betriebsvermögen  ...                       Grundstück
# 274                         Betriebsvermögen  ...                            Boden
# 275                                     Land  ...                       Freibetrag
# 276                                     Land  ...                           Gewinn
# 277                                     Land  ...                  Forstwirtschaft
# 278                                     Land  ...                  Forstwirtschaft
# 279                                     Land  ...                  Forstwirtschaft
# 280                                     Land  ...                        Forstwirt
# 281                                     Land  ...                        Forstwirt
# 282                                     Land  ...                        Forstwirt
# 283                                     Land  ...                        Forstwirt
# 284                                     Land  ...                        Forstwirt
# 285                                     Erla  ...                       Freibetrag
# 286                                    erdem  ...                       § 14a EStG
# 287                               Freibetrag  ...                            Sinne
# 288                               Freibetrag  ...                              Abs
# 289                               Freibetrag  ...                              Abs
# 290                               Freibetrag  ...                              Abs
# 291                               Freibetrag  ...                              Abs
# 292                               Freibetrag  ...                        § 14 EStG
# 293                      Steuervergünstigung  ...                              Abs
# 294                                      ert  ...                          Betrieb
# 295                                    Sinne  ...                              Abs
# 296                               steuerlich  ...                        Abfindung
# 297                              Vermächtnis  ...            gesetzlichen Erbfolge
# 298                                  getilgt  ...                         Schulden
# 299                                   worden  ...                       § 14a EStG
# 300                     Veranlagungszeitraum  ...                      Veräußerung
# 301                                   Gewinn  ...                              Abs
# 302                                   Gewinn  ...                  Wirtschaftsjahr
# 303                              Veräußerung  ...                          Betrieb
# 304                              Veräußerung  ...                              Abs
# 305                              Veräußerung  ...                              Abs
# 306                              Veräußerung  ...                          1. Juli
# 307                                 Schulden  ...                          Betrieb
# 308                                 Schulden  ...                          Betrieb
# 309                                 Schulden  ...                          Betrieb
# 310                                 Schulden  ...                     anderen land
# 311                                 Schulden  ...  land- und forstwirtschaftlichen
# 312                                 Schulden  ...  land- und forstwirtschaftlichen
# 313                                 Schulden  ...  land- und forstwirtschaftlichen
# 314                                      DMb  ...                  Wirtschaftsjahr
# 315                                  Betrieb  ...                      Abfindungen
# 316                                  Betrieb  ...                        Abfindung
# 317                                  Betrieb  ...                            Boden
# 318                                  Betrieb  ...                              bzw
# 319                          Forstwirtschaft  ...                  Wirtschaftsjahr
# 320                                Forstwirt  ...                  Wirtschaftsjahr
# 321                           Privatvermögen  ...                    Steuerpflicht
# 322                           Privatvermögen  ...                 Steuerpflichtige
# 323                           Ertragsmeßzahl  ...               landwirtschaftlich
# 324                          Betriebsaufgabe  ...               landwirtschaftlich
# 325                                      ert  ...                              Abs
# 326                       landwirtschaftlich  ...                       Grundstück
# 327                       landwirtschaftlich  ...                       Grundstück
# 328                       landwirtschaftlich  ...                       Grundstück
# 329                       landwirtschaftlich  ...                       Grundstück
# 330                               Eigentümer  ...                       Grundstück
#
# [331 rows x 3 columns]

# %% [markdown]
# **Temp Relation Dataframe Cleaning**

# %%
pd.set_option('display.max_rows', None)

# %%
temp_relation_df.shape
# Out:
# (1340, 3)

# %%
def isLawPara(inputString):
  matched = re.match("§[ §a-zA-Z0-9,.]+", inputString)
  is_match = bool(matched)
  return is_match

# %%
# Remove duplicates
temp_relation_df = temp_relation_df.drop_duplicates()
law_para_list = []
for index, rows in temp_relation_df.iterrows():
  word1 = rows["Word1"]
  word2 = rows["Word2"]
  relation = rows["Relation"]
  # filter out rows with Law Para in different Dataframe
  if isLawPara(word1) or isLawPara(word2):
    print(word1+" | " + relation+ " | " +word2)
# Out:
# ausländische Einkünfte --- Einkünfte nach § 34d----§ 34d EStG
# Einkünfte --- die von § 2----§ 2 AStG
# Anwendung --- des § 2----§ 2 AStG
# Steuerermäßigung --- des § 34c----§ 34c EStG
# Zugangsfiktion --- des § 123----§ 123 AO
# AStG --- i.V.m. § 17----§ 17 EStG
# Besteuerung --- nach § 6 AStG----§ 6 AStG ausl
# Vorschrift --- des § 17----§ 17 EStG
# Anschaffungskosten --- sowie § 9----§ 9 BewG
# Werbungskosten --- nach § 160----§ 160 AO
# Verfahren --- nach § 18----§ 18 AStG
# vorläufig --- nach § 165----§ 165 AO
# Außensteuergesetzes --- §§Fassung----§§Fassung desf
